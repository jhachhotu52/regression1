# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/Aslam Khan/Desktop/bangalore house price prediction OHE-data.csv")
df=data
df.head()
# Out:
#    bath  balcony  price  total_sqft_int  bhk  price_per_sqft  \
# 0   3.0      2.0  150.0          1672.0    3     8971.291866
# 1   3.0      3.0  149.0          1750.0    3     8514.285714
# 2   3.0      2.0  150.0          1750.0    3     8571.428571
# 3   2.0      2.0   40.0          1250.0    2     3200.000000
# 4   2.0      2.0   83.0          1200.0    2     6916.666667
#
#    area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                              1                        0
# 1                              0                        1
# 2                              1                        0
# 3                              1                        0
# 4                              0                        0
#
#    area_typePlot  Area  availability_Ready To Move  ...  \
# 0                    0                           1  ...
# 1                    0                           1  ...
# 2                    0                           1  ...
# ...

# %% [markdown]
# #### EDA exploratery data analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7120 entries, 0 to 7119
# Columns: 108 entries, bath to location_Tumkur Road
# dtypes: float64(5), int64(103)
# memory usage: 5.9 MB

# %%
df.describe()## we have define the neumaric value
# Out:
#               bath      balcony        price  total_sqft_int          bhk  \
# count  7120.000000  7120.000000  7120.000000     7120.000000  7120.000000
# mean      2.390871     1.572759    96.454991     1479.729806     2.465169
# std       0.876822     0.770583   116.185034      913.779769     0.841520
# min       1.000000     0.000000    10.000000      350.000000     1.000000
# 25%       2.000000     1.000000    49.230000     1100.000000     2.000000
# 50%       2.000000     2.000000    69.000000     1255.000000     2.000000
# 75%       3.000000     2.000000   104.000000     1640.250000     3.000000
# max       9.000000     3.000000  2912.000000    30400.000000     9.000000
#
#        price_per_sqft  area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# count     7120.000000                    7120.000000              7120.000000
# mean      5923.806855                       0.750702                 0.182303
# ...

# %%
df.isnull()##
# Out:
#        bath  balcony  price  total_sqft_int    bhk  price_per_sqft  \
# 0     False    False  False           False  False           False
# 1     False    False  False           False  False           False
# 2     False    False  False           False  False           False
# 3     False    False  False           False  False           False
# 4     False    False  False           False  False           False
# ...     ...      ...    ...             ...    ...             ...
# 7115  False    False  False           False  False           False
# 7116  False    False  False           False  False           False
# 7117  False    False  False           False  False           False
# 7118  False    False  False           False  False           False
# 7119  False    False  False           False  False           False
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                             False                    False
# ...

# %%
df.fillna(0)
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
df.isnull().sum()## define the missing value
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
df.columns## # definet the columns
# Out:
# Index(['bath', 'balcony', 'price', 'total_sqft_int', 'bhk', 'price_per_sqft',
#        'area_typeSuper built-up  Area', 'area_typeBuilt-up  Area',
#        'area_typePlot  Area', 'availability_Ready To Move',
#        ...
#        'location_Kalena Agrahara', 'location_Horamavu Agara',
#        'location_Vidyaranyapura', 'location_BTM 2nd Stage',
#        'location_Hebbal Kempapura', 'location_Hosur Road',
#        'location_Horamavu Banaswadi', 'location_Domlur',
#        'location_Mahadevpura', 'location_Tumkur Road'],
#       dtype='object', length=108)

# %%
df.shape### we have deifne the row and columns
# Out:
# (7120, 108)

# %%
######## we have define the x and y dependent varible

# %%
x = df[['bath', 'balcony', 'price', 'total_sqft_int', 'bhk', 'price_per_sqft',
       'area_typeSuper built-up  Area', 'area_typeBuilt-up  Area',
       'area_typePlot  Area', 'availability_Ready To Move']]
y = df['bath']

# %%
x
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
y
# Out:
# 0       3.0
# 1       3.0
# 2       3.0
# 3       2.0
# 4       2.0
#        ...
# 7115    3.0
# 7116    3.0
# 7117    2.0
# 7118    2.0
# 7119    2.0
# Name: bath, Length: 7120, dtype: float64

# %%
x = df.iloc[:,0:-1].values
x
# Out:
# array([[  3.,   2., 150., ...,   0.,   0.,   0.],
#        [  3.,   3., 149., ...,   0.,   0.,   0.],
#        [  3.,   2., 150., ...,   0.,   0.,   0.],
#        ...,
#        [  2.,   1.,  48., ...,   0.,   0.,   0.],
#        [  2.,   1.,  55., ...,   0.,   0.,   0.],
#        [  2.,   1.,  78., ...,   0.,   0.,   0.]])

# %%
y = df.iloc[0:1].values

# %%
y
# Out:
# array([[3.00000000e+00, 2.00000000e+00, 1.50000000e+02, 1.67200000e+03,
#         3.00000000e+00, 8.97129187e+03, 1.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 1.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
# ...

# %%
x.shape  ###define the roq and columns
# Out:
# (7120, 107)

# %%
y.shape
# Out:
# (7120,)

# %%
x
# Out:
#       bath  balcony  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0          1672.0    3     8971.291866
# 1      3.0      3.0          1750.0    3     8514.285714
# 2      3.0      2.0          1750.0    3     8571.428571
# 3      2.0      2.0          1250.0    2     3200.000000
# 4      2.0      2.0          1200.0    2     6916.666667
# ...    ...      ...             ...  ...             ...
# 7115   3.0      2.0          2900.0    3    11206.896552
# 7116   3.0      1.0          1780.0    3     4765.730337
# 7117   2.0      1.0           880.0    2     5454.545455
# 7118   2.0      1.0          1000.0    2     5500.000000
# 7119   2.0      1.0          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# 1                                 0                        1
# 2                                 1                        0
# ...

# %%
y
# Out:
# 0       150.00
# 1       149.00
# 2       150.00
# 3        40.00
# 4        83.00
#          ...
# 7115    325.00
# 7116     84.83
# 7117     48.00
# 7118     55.00
# 7119     78.00
# Name: price, Length: 7120, dtype: float64

# %%
## we have split our data training and testing
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (5696, 107)

# %%
y_train.shape
# Out:
# (5696,)

# %%
x_train
# Out:
#       bath  balcony  total_sqft_int  bhk  price_per_sqft  \
# 2191   2.0      2.0          1550.0    3     5290.322581
# 3289   3.0      3.0          1650.0    3    13333.333333
# 2077   2.0      1.0          1000.0    2     2500.000000
# 443    2.0      1.0           900.0    2     6666.666667
# 2812   2.0      1.0          1285.0    2     4669.260700
# ...    ...      ...             ...  ...             ...
# 3772   2.0      1.0           929.0    2     4951.560818
# 5191   2.0      2.0          1050.0    2     5095.238095
# 5226   2.0      2.0          1145.0    2     3999.126638
# 5390   3.0      2.0          2415.0    3    16521.739130
# 860    2.0      2.0          1365.0    2     5347.985348
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 2191                              1                        0
# 3289                              0                        1
# 2077                              1                        0
# ...

# %%
y_train
# Out:
# 2191     82.00
# 3289    220.00
# 2077     25.00
# 443      60.00
# 2812     60.00
#          ...
# 3772     46.00
# 5191     53.50
# 5226     45.79
# 5390    399.00
# 860      73.00
# Name: price, Length: 5696, dtype: float64

# %%
##  import the package

# %%
from sklearn.neighbors import KNeighborsRegressor
from math import sqrt
from sklearn.metrics import r2_score

# %%
###we trained our data for model training

# %%
knn = KNeighborsRegressor(n_neighbors=3)### we have predict the model
knn.fit(x_train,y_train)
pred = knn.predict(x_test)

# %%
### we have predict our data

# %%
pred = knn.predict(x_test)
pred
# Out:
# array([46.66666667, 59.33333333, 65.        , ..., 56.66666667,
#        26.33333333, 49.33      ])

# %%
knn.score(x_test,y_test)
# Out:
# 0.9861876109967744

# %%
## predict the value of house

# %%
x_test.iloc[-1,:]
# Out:
# bath                              2.000000
# balcony                           1.000000
# total_sqft_int                 1092.000000
# bhk                               2.000000
# price_per_sqft                 4487.179487
#                                   ...
# location_Hosur Road               0.000000
# location_Horamavu Banaswadi       0.000000
# location_Domlur                   0.000000
# location_Mahadevpura              0.000000
# location_Tumkur Road              0.000000
# Name: 1817, Length: 107, dtype: float64

# %%
knn.predict([x_test.iloc[-1,:]])
# Out:
# C:\Users\Aslam Khan\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([49.33])

# %%
y_test.iloc[-1]
# Out:
# 49.0

# %%
y_pred =knn.predict(x_test)
y_pred
# Out:
# array([46.66666667, 59.33333333, 65.        , ..., 56.66666667,
#        26.33333333, 49.33      ])

# %%
###done
